# %%
import json
import os
import argparse
from tqdm import tqdm
from allennlp.predictors.predictor import Predictor
import torch

# %%
def batch(iterable, n=1):
    l = len(iterable)
    for ndx in range(0, l, n):
        yield iterable[ndx:min(ndx + n, l)]
        
        
def read_from_json(filepath, filename):
    """
    output: list of dicts 
    """
    with open(os.path.join(filepath, filename, 'r')) as f:
        data = []
        for line in f.readlines():
            data.append(json.loads(line))
    return data
            
def read_from_txt(filepath, filename):
    # OUTPUT: LIST -> EACH LINE IN THE FILE IS AN ITEM IN LIST
    with open(os.path.join(filepath, filename), 'r') as f:
        data = []
        for line in f:
            data.append(line.strip())
    return data

def dump_json(filepath, filename, data):
            
    with open(os.path.join(filepath, filename), 'w') as f:
        for sent in tqdm(data):
            json.dump(sent, f)
            f.write('\n')
            
def dictify_sentences(sents):
    return [{'sentence':sent} for sent in sents]

# %%
if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--data_path', default='/home/zijiao/work/data/mscoco',
                        help='path to datasets')
    parser.add_argument('--output_path', required=True,
                       help='output processed data to the path')
    parser.add_argument('--batch_size', default=50, type=int,
                       help='size of batches')
    args = parser.parse_args()
    
    batch_size = args.batch_size
    
    if os.path.exists(args.output_path):
        print(f'dir {args.output_path} exists')
    os.system('mkdir {:s}'.format(args.output_path))
    if torch.cuda.is_available():
        cuda_device = 0
    else:
        cuda_device = -1
    # get predictor of srl
    predictor = Predictor.from_path("https://s3-us-west-2.amazonaws.com/allennlp/models/bert-base-srl-2019.06.17.tar.gz", cuda_device=cuda_device)

    # get srls for each train sentence
    train = read_from_txt(args.data_path, 'train_caps.txt')
    train_dicts = dictify_sentences(train)
    
    train_srls = []
    for ba in tqdm(batch(train_dicts, n=batch_size), total=len(train_dicts)//batch_size):
        train_srls.extend(predictor.predict_batch_json(ba))
    
    dump_json(args.output_path, 'train_srls.json', train_srls)

    # get srls for each test sentence
    test = read_from_txt(args.data_path, 'test_caps.txt')
    test_dicts = dictify_sentences(test)
    
    test_srls = []
    for ba in tqdm(batch(test_dicts, n=batch_size), total=len(test_dicts)//batch_size):
        test_srls.extend(predictor.predict_batch_json(ba))

    dump_json(args.output_path, 'test_srls.json', test_srls)
# Out:
# usage: ipykernel_launcher.py [-h] [--data_path DATA_PATH] --output_path
#                              OUTPUT_PATH [--batch_size BATCH_SIZE]
# ipykernel_launcher.py: error: the following arguments are required: --output_path
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
#     with open(os.path.join(args.data_path, 'train_caps.txt'), 'r') as f:
#         train = []
#         for line in f:
#             train.append(line.strip())

#     train_dicts = [{'sentence':sent} for sent in train]
#     with open(os.path.join(args.output_path, 'train_srls.json'), 'w') as f:
#         for sent in tqdm(train_srls):
#             json.dump(sent, f)
#             f.write('\n')
        
#     with open(os.path.join(args.data_path, 'test_caps.txt'), 'r') as f:
#         test = []
#         for line in f:
#             test.append(line.strip())

#     test_dicts = [{'sentence':sent} for sent in test]
#     with open(os.path.join(args.output_path, 'test_srls.json'), 'w') as f:
# #         for sent in tqdm(test_srls):
# #             json.dump(sent, f)
# #             f.write('\n')
#     result = predictor.predict(
#       sentence="Did Uriah honestly think he could beat the game in under three hours?"
#     )

# %%
ls
# Out:
# 'Create dataset.ipynb'   output/                 srl_label_getter.ipynb
#  experiments/            README.md               train_new.json
#  LICENSE                 srl_json_reader.ipynb

# %%
predictor = Predictor.from_path("https://s3-us-west-2.amazonaws.com/allennlp/models/bert-base-srl-2019.06.17.tar.gz", cuda_device=0)

    # get srls for each train sentence
val = read_from_txt('../data/mscoco/', 'dev_caps.txt')
val_dicts = dictify_sentences(val)
    
val_srls = []
for i, ba in tqdm(enumerate(batch(val_dicts, n=50)), total=len(val_dicts)//50):
    if i >= 80:
        val_srls.extend(predictor.predict_batch_json(ba))
    
dump_json('./output/', 'val1000_srls.json', val_srls)
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 17.76it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 34861.31it/s]

# %%
val_srls
# Out:
# [{'verbs': [],
#   'words': ['An',
#    'old',
#    'brick',
#    'building',
#    'along',
#    'side',
#    'of',
#    'a',
#    'river']},
#  {'verbs': [],
#   'words': ['a',
#    'wooden',
#    'street',
#    'sign',
#    'next',
#    'to',
#    'a',
#    'tree',
#    'and',
#    'a',
#    'river']},
#  {'verbs': [{'verb': 'says',
#     'description': 'A flooded road and [ARG0: a sign] [R-ARG0: that] [V: says] , ` [ARG1: ` East Street `] ` .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'B-R-ARG0',
#      'B-V',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O']}],
#   'words': ['A',
#    'flooded',
#    'road',
#    'and',
#    'a',
#    'sign',
#    'that',
#    'says',
#    ',',
#    '`',
#    '`',
#    'East',
#    'Street',
#    '`',
#    '`',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'A black sign that [V: is] standing in the grass .',
#     'tags': ['O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'standing',
#     'description': '[ARG1: A black sign] [R-ARG1: that] is [V: standing] [ARG2: in the grass] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-R-ARG1',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'black',
#    'sign',
#    'that',
#    'is',
#    'standing',
#    'in',
#    'the',
#    'grass',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'A street next to a large building [V: is] flooded .',
#     'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O']},
#    {'verb': 'flooded',
#     'description': '[ARG1: A street next to a large building] is [V: flooded] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'B-V',
#      'O']}],
#   'words': ['A',
#    'street',
#    'next',
#    'to',
#    'a',
#    'large',
#    'building',
#    'is',
#    'flooded',
#    '.']},
#  {'verbs': [],
#   'words': ['Roadway',
#    'signs',
#    'on',
#    'post',
#    'on',
#    'sidewalk',
#    'of',
#    'large',
#    'urban',
#    'city',
#    '.']},
#  {'verbs': [],
#   'words': ['A',
#    'road',
#    'sign',
#    'for',
#    'a',
#    'freeway',
#    'entrance',
#    'outside',
#    'of',
#    'a',
#    'building',
#    '.']},
#  {'verbs': [{'verb': 'sitting',
#     'description': '[ARG1: A traffic sign] [V: sitting] [ARG2: below a building] [ARGM-LOC: next to bikes] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['A',
#    'traffic',
#    'sign',
#    'sitting',
#    'below',
#    'a',
#    'building',
#    'next',
#    'to',
#    'bikes',
#    '.']},
#  {'verbs': [{'verb': 'parked',
#     'description': '[ARG1: a number of bikes] [V: parked] [ARG2: near one another]',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2']}],
#   'words': ['a', 'number', 'of', 'bikes', 'parked', 'near', 'one', 'another']},
#  {'verbs': [{'verb': 'are',
#     'description': 'Some bicycles [V: are] leaning against a pole with south I5 signs on it .',
#     'tags': ['O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'leaning',
#     'description': '[ARG0: Some bicycles] are [V: leaning] [ARG2: against a pole with south I5 signs on it] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['Some',
#    'bicycles',
#    'are',
#    'leaning',
#    'against',
#    'a',
#    'pole',
#    'with',
#    'south',
#    'I5',
#    'signs',
#    'on',
#    'it',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'A train [V: is] passing another train sitting on a track .',
#     'tags': ['O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'passing',
#     'description': '[ARG0: A train] is [V: passing] [ARG1: another train sitting on a track] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'sitting',
#     'description': 'A train is passing [ARG1: another train] [V: sitting] [ARG2: on a track] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'train',
#    'is',
#    'passing',
#    'another',
#    'train',
#    'sitting',
#    'on',
#    'a',
#    'track',
#    '.']},
#  {'verbs': [{'verb': 'moving',
#     'description': '[ARG1: Commercial train] [V: moving] [ARGM-MNR: quickly] passed a commuter rail',
#     'tags': ['B-ARG1', 'I-ARG1', 'B-V', 'B-ARGM-MNR', 'O', 'O', 'O', 'O']},
#    {'verb': 'passed',
#     'description': '[ARG0: Commercial train] [ARGM-ADV: moving quickly] [V: passed] [ARG1: a commuter rail]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-ARGM-ADV',
#      'I-ARGM-ADV',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1']}],
#   'words': ['Commercial',
#    'train',
#    'moving',
#    'quickly',
#    'passed',
#    'a',
#    'commuter',
#    'rail']},
#  {'verbs': [{'verb': 'passes',
#     'description': '[ARG1: The train] [V: passes] [ARGM-DIR: by another train] [ARGM-TMP: as it moves through a rail yard] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O']},
#    {'verb': 'moves',
#     'description': 'The train passes by another train as [ARG1: it] [V: moves] [ARGM-DIR: through a rail yard] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'B-V',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'O']}],
#   'words': ['The',
#    'train',
#    'passes',
#    'by',
#    'another',
#    'train',
#    'as',
#    'it',
#    'moves',
#    'through',
#    'a',
#    'rail',
#    'yard',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'a train that [V: is] rolling by a large building',
#     'tags': ['O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'rolling',
#     'description': '[ARG1: a train] [R-ARG1: that] is [V: rolling] [ARGM-DIR: by a large building]',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-R-ARG1',
#      'O',
#      'B-V',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR']}],
#   'words': ['a',
#    'train',
#    'that',
#    'is',
#    'rolling',
#    'by',
#    'a',
#    'large',
#    'building']},
#  {'verbs': [{'verb': 'moving',
#     'description': 'A [V: moving] [ARG1: train] pulling tanks down the tracks .',
#     'tags': ['O', 'B-V', 'B-ARG1', 'O', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'pulling',
#     'description': '[ARG0: A moving train] [V: pulling] [ARG1: tanks] [ARGM-DIR: down the tracks] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'O']}],
#   'words': ['A',
#    'moving',
#    'train',
#    'pulling',
#    'tanks',
#    'down',
#    'the',
#    'tracks',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'A steam engine strain [V: is] decorated to look like a character from ` ` Thomas the Train ` ` books .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'decorated',
#     'description': '[ARG1: A steam engine strain] is [V: decorated] [ARGM-PNC: to look like a character from ` ` Thomas the Train ` ` books] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'B-V',
#      'B-ARGM-PNC',
#      'I-ARGM-PNC',
#      'I-ARGM-PNC',
#      'I-ARGM-PNC',
#      'I-ARGM-PNC',
#      'I-ARGM-PNC',
#      'I-ARGM-PNC',
#      'I-ARGM-PNC',
#      'I-ARGM-PNC',
#      'I-ARGM-PNC',
#      'I-ARGM-PNC',
#      'I-ARGM-PNC',
#      'I-ARGM-PNC',
#      'I-ARGM-PNC',
#      'O']},
#    {'verb': 'look',
#     'description': '[ARG0: A steam engine strain] is decorated to [V: look] [ARG1: like a character from ` ` Thomas the Train ` ` books] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A',
#    'steam',
#    'engine',
#    'strain',
#    'is',
#    'decorated',
#    'to',
#    'look',
#    'like',
#    'a',
#    'character',
#    'from',
#    '`',
#    '`',
#    'Thomas',
#    'the',
#    'Train',
#    '`',
#    '`',
#    'books',
#    '.']},
#  {'verbs': [],
#   'words': ['A',
#    'green',
#    'train',
#    'engine',
#    'with',
#    'a',
#    'face',
#    'on',
#    'it',
#    '.']},
#  {'verbs': [{'verb': 'Cartooned',
#     'description': '[V: Cartooned] faced green [ARG0: locomotive] tended to by railroad worker .',
#     'tags': ['B-V', 'O', 'O', 'B-ARG0', 'O', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'faced',
#     'description': 'Cartooned [V: faced] [ARG0: green locomotive] tended to by railroad worker .',
#     'tags': ['O', 'B-V', 'B-ARG0', 'I-ARG0', 'O', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'tended',
#     'description': '[ARG1: Cartooned faced green locomotive] [V: tended] [ARG2: to] [ARG0: by railroad worker] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O']}],
#   'words': ['Cartooned',
#    'faced',
#    'green',
#    'locomotive',
#    'tended',
#    'to',
#    'by',
#    'railroad',
#    'worker',
#    '.']},
#  {'verbs': [{'verb': 'working',
#     'description': '[ARG0: a person] [V: working] [ARG1: on a train] [ARGM-LOC: on a train track]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC']}],
#   'words': ['a',
#    'person',
#    'working',
#    'on',
#    'a',
#    'train',
#    'on',
#    'a',
#    'train',
#    'track']},
#  {'verbs': [{'verb': 'being',
#     'description': 'A green Thomas the Train locomotive [V: being] worked on',
#     'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O']},
#    {'verb': 'worked',
#     'description': '[ARG0: A green Thomas the Train locomotive] being [V: worked] [ARG1: on]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'B-ARG1']}],
#   'words': ['A',
#    'green',
#    'Thomas',
#    'the',
#    'Train',
#    'locomotive',
#    'being',
#    'worked',
#    'on']},
#  {'verbs': [],
#   'words': ['a',
#    'yellow',
#    'tram',
#    'some',
#    'mountains',
#    'snow',
#    'and',
#    'trees']},
#  {'verbs': [{'verb': 'traveling',
#     'description': '[ARG0: A short train] [V: traveling] [ARG1: through a mountainous landscape]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1']}],
#   'words': ['A',
#    'short',
#    'train',
#    'traveling',
#    'through',
#    'a',
#    'mountainous',
#    'landscape']},
#  {'verbs': [{'verb': 'sits',
#     'description': '[ARG1: A train] [V: sits] [ARG2: on the tracks] [ARGM-LOC: in front of a mountain range] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['A',
#    'train',
#    'sits',
#    'on',
#    'the',
#    'tracks',
#    'in',
#    'front',
#    'of',
#    'a',
#    'mountain',
#    'range',
#    '.']},
#  {'verbs': [{'verb': 'coming',
#     'description': '[ARG1: A yellow passenger train] [V: coming] [ARGM-DIR: down the tracks] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'O']}],
#   'words': ['A',
#    'yellow',
#    'passenger',
#    'train',
#    'coming',
#    'down',
#    'the',
#    'tracks',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'A train [V: is] riding the tracks near a mountain range .',
#     'tags': ['O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'riding',
#     'description': '[ARG0: A train] is [V: riding] [ARG1: the tracks near a mountain range] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A',
#    'train',
#    'is',
#    'riding',
#    'the',
#    'tracks',
#    'near',
#    'a',
#    'mountain',
#    'range',
#    '.']},
#  {'verbs': [{'verb': 'riding',
#     'description': '[ARG0: A gray train] [V: riding] [ARG1: on a track] [ARGM-ADV: as people are walking] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'O']},
#    {'verb': 'are',
#     'description': 'A gray train riding on a track as people [V: are] walking .',
#     'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O']},
#    {'verb': 'walking',
#     'description': 'A gray train riding on a track as [ARG0: people] are [V: walking] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'O',
#      'B-V',
#      'O']}],
#   'words': ['A',
#    'gray',
#    'train',
#    'riding',
#    'on',
#    'a',
#    'track',
#    'as',
#    'people',
#    'are',
#    'walking',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': '[ARG1: a train] [R-ARG1: that] [V: is] [ARG2: on a train track that s next to a fence]',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-R-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2']},
#    {'verb': 's',
#     'description': 'a train that is on [ARG1: a train track] [R-ARG1: that] [V: s] [ARG2: next to a fence]',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-R-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2']}],
#   'words': ['a',
#    'train',
#    'that',
#    'is',
#    'on',
#    'a',
#    'train',
#    'track',
#    'that',
#    's',
#    'next',
#    'to',
#    'a',
#    'fence']},
#  {'verbs': [{'verb': 'sitting',
#     'description': '[ARG1: Train] [V: sitting] [ARG2: on track] [ARGM-PRD: with another track beside] .',
#     'tags': ['B-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'B-ARGM-PRD',
#      'I-ARGM-PRD',
#      'I-ARGM-PRD',
#      'I-ARGM-PRD',
#      'O']}],
#   'words': ['Train',
#    'sitting',
#    'on',
#    'track',
#    'with',
#    'another',
#    'track',
#    'beside',
#    '.']},
#  {'verbs': [{'verb': 'sitting',
#     'description': '[ARG1: A train with a red stop sign Cal train logo] [V: sitting] [ARG2: on the side of it] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'train',
#    'with',
#    'a',
#    'red',
#    'stop',
#    'sign',
#    'Cal',
#    'train',
#    'logo',
#    'sitting',
#    'on',
#    'the',
#    'side',
#    'of',
#    'it',
#    '.']},
#  {'verbs': [{'verb': 'passing',
#     'description': '[ARG0: Train engine] [V: passing] [ARG1: an outside station platform] , [ARGM-LOC: in California] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['Train',
#    'engine',
#    'passing',
#    'an',
#    'outside',
#    'station',
#    'platform',
#    ',',
#    'in',
#    'California',
#    '.']},
#  {'verbs': [{'verb': 'tagged',
#     'description': 'A [V: tagged] [ARG1: cow] and a calf lying in a field .',
#     'tags': ['O', 'B-V', 'B-ARG1', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'lying',
#     'description': '[ARG1: A tagged cow and a calf] [V: lying] [ARG2: in a field] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'tagged',
#    'cow',
#    'and',
#    'a',
#    'calf',
#    'lying',
#    'in',
#    'a',
#    'field',
#    '.']},
#  {'verbs': [{'verb': 'laying',
#     'description': '[ARG1: A black cow and a brown calf] [V: laying] [ARGM-MNR: together] [ARG2: on some grass]',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARGM-MNR',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2']}],
#   'words': ['A',
#    'black',
#    'cow',
#    'and',
#    'a',
#    'brown',
#    'calf',
#    'laying',
#    'together',
#    'on',
#    'some',
#    'grass']},
#  {'verbs': [{'verb': 'lying',
#     'description': '[ARG1: A cow with a tag on its ear] [V: lying] [ARGM-DIR: down] [ARGM-LOC: next to a baby cow] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARGM-DIR',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['A',
#    'cow',
#    'with',
#    'a',
#    'tag',
#    'on',
#    'its',
#    'ear',
#    'lying',
#    'down',
#    'next',
#    'to',
#    'a',
#    'baby',
#    'cow',
#    '.']},
#  {'verbs': [{'verb': 'laying',
#     'description': '[ARG1: A large black cow] [V: laying] [ARG2: next to a small brown cow] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'large',
#    'black',
#    'cow',
#    'laying',
#    'next',
#    'to',
#    'a',
#    'small',
#    'brown',
#    'cow',
#    '.']},
#  {'verbs': [{'verb': 'sitting',
#     'description': '[ARG1: A cow and calf] [V: sitting] [ARG2: on the ground] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A', 'cow', 'and', 'calf', 'sitting', 'on', 'the', 'ground', '.']},
#  {'verbs': [{'verb': 'driving',
#     'description': '[ARG0: A red fire truck] [V: driving] [ARGM-DIR: into a parking lot] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'O']}],
#   'words': ['A',
#    'red',
#    'fire',
#    'truck',
#    'driving',
#    'into',
#    'a',
#    'parking',
#    'lot',
#    '.']},
#  {'verbs': [{'verb': 'are',
#     'description': 'People [V: are] standing near a fence as a fire pickup truck arrives .',
#     'tags': ['O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'standing',
#     'description': '[ARG1: People] are [V: standing] [ARG2: near a fence] [ARGM-TMP: as a fire pickup truck arrives] .',
#     'tags': ['B-ARG1',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O']},
#    {'verb': 'arrives',
#     'description': 'People are standing near a fence as [ARG1: a fire pickup truck] [V: arrives] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'O']}],
#   'words': ['People',
#    'are',
#    'standing',
#    'near',
#    'a',
#    'fence',
#    'as',
#    'a',
#    'fire',
#    'pickup',
#    'truck',
#    'arrives',
#    '.']},
#  {'verbs': [],
#   'words': ['A',
#    'parking',
#    'lot',
#    'with',
#    'several',
#    'cars',
#    'and',
#    'a',
#    'truck',
#    '.']},
#  {'verbs': [{'verb': 'standing',
#     'description': 'A parking lot area with various cars and a fire department pick - up truck near [ARG1: two people] [V: standing] [ARG2: in the lot] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'parking',
#    'lot',
#    'area',
#    'with',
#    'various',
#    'cars',
#    'and',
#    'a',
#    'fire',
#    'department',
#    'pick',
#    '-',
#    'up',
#    'truck',
#    'near',
#    'two',
#    'people',
#    'standing',
#    'in',
#    'the',
#    'lot',
#    '.']},
#  {'verbs': [{'verb': 'standing',
#     'description': '[ARG1: two people] [V: standing] [ARG2: at a gate] [ARGM-COM: with a group of cars]',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'B-ARGM-COM',
#      'I-ARGM-COM',
#      'I-ARGM-COM',
#      'I-ARGM-COM',
#      'I-ARGM-COM']}],
#   'words': ['two',
#    'people',
#    'standing',
#    'at',
#    'a',
#    'gate',
#    'with',
#    'a',
#    'group',
#    'of',
#    'cars']},
#  {'verbs': [{'verb': 'sleeping',
#     'description': '[ARG0: a white cat] [V: sleeping] [ARGM-LOC: in a wicker chair covered with a blanket]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC']},
#    {'verb': 'covered',
#     'description': 'a white cat sleeping in a wicker chair [V: covered] [ARG2: with a blanket]',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2']}],
#   'words': ['a',
#    'white',
#    'cat',
#    'sleeping',
#    'in',
#    'a',
#    'wicker',
#    'chair',
#    'covered',
#    'with',
#    'a',
#    'blanket']},
#  {'verbs': [{'verb': 'sleeps',
#     'description': '[ARG0: A white cat] [V: sleeps] [ARGM-LOC: in a blanketed basket] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['A',
#    'white',
#    'cat',
#    'sleeps',
#    'in',
#    'a',
#    'blanketed',
#    'basket',
#    '.']},
#  {'verbs': [{'verb': 'curled',
#     'description': '[ARG1: White cat] [V: curled] up [ARGM-PRD: asleep] [ARGM-LOC: in a blanketed chair]',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'O',
#      'B-ARGM-PRD',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC']}],
#   'words': ['White',
#    'cat',
#    'curled',
#    'up',
#    'asleep',
#    'in',
#    'a',
#    'blanketed',
#    'chair']},
#  {'verbs': [{'verb': 'sleeping',
#     'description': '[ARG0: A white long - haired adult cat] [V: sleeping] [ARGM-LOC: in a wicker chair] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['A',
#    'white',
#    'long',
#    '-',
#    'haired',
#    'adult',
#    'cat',
#    'sleeping',
#    'in',
#    'a',
#    'wicker',
#    'chair',
#    '.']},
#  {'verbs': [{'verb': 'sleeping',
#     'description': '[ARG0: A cat] [V: sleeping] [ARGM-LOC: in a wicker seat] [ARGM-MNR: with a green blanket]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'B-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR']}],
#   'words': ['A',
#    'cat',
#    'sleeping',
#    'in',
#    'a',
#    'wicker',
#    'seat',
#    'with',
#    'a',
#    'green',
#    'blanket']},
#  {'verbs': [{'verb': 'standing',
#     'description': '[ARG1: A cat] [V: standing] [ARG2: in front of a TV showing a dog in a cage] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']},
#    {'verb': 'showing',
#     'description': 'A cat standing in front of [ARG0: a TV] [V: showing] [ARG1: a dog in a cage] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A',
#    'cat',
#    'standing',
#    'in',
#    'front',
#    'of',
#    'a',
#    'TV',
#    'showing',
#    'a',
#    'dog',
#    'in',
#    'a',
#    'cage',
#    '.']},
#  {'verbs': [{'verb': 'looks',
#     'description': '[ARG0: A cat] [V: looks] [ARG1: at a dog] [ARGM-LOC: on television]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC']}],
#   'words': ['A', 'cat', 'looks', 'at', 'a', 'dog', 'on', 'television']},
#  {'verbs': [{'verb': 'looks',
#     'description': '[ARG0: A cat] [V: looks] [ARG1: at a dog that is on tv] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'is',
#     'description': 'A cat looks at [ARG1: a dog] [R-ARG1: that] [V: is] [ARG2: on tv] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'B-R-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'cat',
#    'looks',
#    'at',
#    'a',
#    'dog',
#    'that',
#    'is',
#    'on',
#    'tv',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'A cat [V: is] looking at a television displaying a dog in a cage .',
#     'tags': ['O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'looking',
#     'description': '[ARG0: A cat] is [V: looking] [ARG1: at a television displaying a dog in a cage] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'displaying',
#     'description': 'A cat is looking at [ARG0: a television] [V: displaying] [ARG1: a dog in a cage] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A',
#    'cat',
#    'is',
#    'looking',
#    'at',
#    'a',
#    'television',
#    'displaying',
#    'a',
#    'dog',
#    'in',
#    'a',
#    'cage',
#    '.']},
#  {'verbs': [{'verb': 'stares',
#     'description': '[ARG0: A cat] [V: stares] [ARG1: at a dog on TV] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A', 'cat', 'stares', 'at', 'a', 'dog', 'on', 'TV', '.']},
#  {'verbs': [{'verb': 'walking',
#     'description': '[ARG0: A herd of elephants] [V: walking] [ARGM-DIR: into a large body of water] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'O']}],
#   'words': ['A',
#    'herd',
#    'of',
#    'elephants',
#    'walking',
#    'into',
#    'a',
#    'large',
#    'body',
#    'of',
#    'water',
#    '.']},
#  {'verbs': [{'verb': 'are',
#     'description': 'a bunch of elephants [V: are] standing by a body of water',
#     'tags': ['O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'standing',
#     'description': '[ARG1: a bunch of elephants] are [V: standing] [ARG2: by a body of water]',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2']}],
#   'words': ['a',
#    'bunch',
#    'of',
#    'elephants',
#    'are',
#    'standing',
#    'by',
#    'a',
#    'body',
#    'of',
#    'water']},
#  {'verbs': [{'verb': 'standing',
#     'description': '[ARG1: a herd of elephants] [V: standing] [ARG2: in a water hole] [ARGM-MNR: with a crowd of people watching]',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'B-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR']},
#    {'verb': 'watching',
#     'description': 'a herd of elephants standing in a water hole with [ARG0: a crowd of people] [V: watching]',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V']}],
#   'words': ['a',
#    'herd',
#    'of',
#    'elephants',
#    'standing',
#    'in',
#    'a',
#    'water',
#    'hole',
#    'with',
#    'a',
#    'crowd',
#    'of',
#    'people',
#    'watching']},
#  {'verbs': [{'verb': 'watching',
#     'description': '[ARG0: some people] [V: watching] [ARG1: a large group of elephants walking into the world]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1']},
#    {'verb': 'walking',
#     'description': 'some people watching [ARG0: a large group of elephants] [V: walking] [ARGM-DIR: into the world]',
#     'tags': ['O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR']}],
#   'words': ['some',
#    'people',
#    'watching',
#    'a',
#    'large',
#    'group',
#    'of',
#    'elephants',
#    'walking',
#    'into',
#    'the',
#    'world']},
#  {'verbs': [{'verb': 'being',
#     'description': 'A herd of elephants [V: being] herded into a river while tourists take photos .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'herded',
#     'description': '[ARG1: A herd of elephants] being [V: herded] [ARG2: into a river] [ARGM-TMP: while tourists take photos] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'B-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'I-ARGM-TMP',
#      'O']},
#    {'verb': 'take',
#     'description': 'A herd of elephants being herded into a river while [ARG0: tourists] [V: take] [ARG1: photos] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG0',
#      'B-V',
#      'B-ARG1',
#      'O']}],
#   'words': ['A',
#    'herd',
#    'of',
#    'elephants',
#    'being',
#    'herded',
#    'into',
#    'a',
#    'river',
#    'while',
#    'tourists',
#    'take',
#    'photos',
#    '.']},
#  {'verbs': [],
#   'words': ['A', 'picture', 'of', 'a', 'dog', 'on', 'a', 'bed', '.']},
#  {'verbs': [{'verb': 'wearing',
#     'description': '[ARG0: A gray dog] [V: wearing] [ARG1: an orange bow tie] laying on a sofa .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'laying',
#     'description': '[ARG1: A gray dog wearing an orange bow tie] [V: laying] [ARG2: on a sofa] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'gray',
#    'dog',
#    'wearing',
#    'an',
#    'orange',
#    'bow',
#    'tie',
#    'laying',
#    'on',
#    'a',
#    'sofa',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'A dog with a bow [V: is] shown sitting on a cushion .',
#     'tags': ['O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'shown',
#     'description': 'A dog with a bow is [V: shown] [ARG1: sitting on a cushion] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'sitting',
#     'description': '[ARG1: A dog with a bow] is shown [V: sitting] [ARG2: on a cushion] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'dog',
#    'with',
#    'a',
#    'bow',
#    'is',
#    'shown',
#    'sitting',
#    'on',
#    'a',
#    'cushion',
#    '.']},
#  {'verbs': [{'verb': 'sitting',
#     'description': '[ARG1: A dog] [V: sitting] [ARG2: on a bed] [ARGM-ADV: wearing an orange bow tie] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'B-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'O']},
#    {'verb': 'wearing',
#     'description': '[ARG0: A dog] sitting on a bed [V: wearing] [ARG1: an orange bow tie] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A',
#    'dog',
#    'sitting',
#    'on',
#    'a',
#    'bed',
#    'wearing',
#    'an',
#    'orange',
#    'bow',
#    'tie',
#    '.']},
#  {'verbs': [{'verb': 'has',
#     'description': '[ARG0: The puppy] [V: has] [ARG1: an orange tie] [ARGM-LOC: on his neck] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['The',
#    'puppy',
#    'has',
#    'an',
#    'orange',
#    'tie',
#    'on',
#    'his',
#    'neck',
#    '.']},
#  {'verbs': [{'verb': 'have',
#     'description': 'A snowy day in a colorful forest where leaves [V: have] already changed colors .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'changed',
#     'description': 'A snowy day in [ARGM-LOC: a colorful forest] [R-ARGM-LOC: where] [ARG1: leaves] have [ARGM-TMP: already] [V: changed] [ARG2: colors] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'B-R-ARGM-LOC',
#      'B-ARG1',
#      'O',
#      'B-ARGM-TMP',
#      'B-V',
#      'B-ARG2',
#      'O']}],
#   'words': ['A',
#    'snowy',
#    'day',
#    'in',
#    'a',
#    'colorful',
#    'forest',
#    'where',
#    'leaves',
#    'have',
#    'already',
#    'changed',
#    'colors',
#    '.']},
#  {'verbs': [],
#   'words': ['a',
#    'small',
#    'boat',
#    'near',
#    'a',
#    'wide',
#    'river',
#    'with',
#    'a',
#    'dense',
#    'forest',
#    'on',
#    'the',
#    'other',
#    'side']},
#  {'verbs': [{'verb': 'View',
#     'description': '[V: View] [ARGM-DIR: from window] [ARGM-DIR: across water] [ARG1: with fall foliaged trees on other bank] .',
#     'tags': ['B-V',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'foliaged',
#     'description': 'View from window across water with [ARG2: fall] [V: foliaged] [ARG1: trees] on other bank .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG2',
#      'B-V',
#      'B-ARG1',
#      'O',
#      'O',
#      'O',
#      'O']}],
#   'words': ['View',
#    'from',
#    'window',
#    'across',
#    'water',
#    'with',
#    'fall',
#    'foliaged',
#    'trees',
#    'on',
#    'other',
#    'bank',
#    '.']},
#  {'verbs': [{'verb': 'View',
#     'description': '[V: View] [ARGM-DIR: from behind a tree of a lake and fall colored tress] [ARGM-LOC: on the other side] .',
#     'tags': ['B-V',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']},
#    {'verb': 'fall',
#     'description': 'View from behind a tree of a lake and [V: fall] [ARG1: colored tress] on the other side .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']}],
#   'words': ['View',
#    'from',
#    'behind',
#    'a',
#    'tree',
#    'of',
#    'a',
#    'lake',
#    'and',
#    'fall',
#    'colored',
#    'tress',
#    'on',
#    'the',
#    'other',
#    'side',
#    '.']},
#  {'verbs': [],
#   'words': ['a',
#    'boat',
#    'some',
#    'water',
#    'and',
#    'some',
#    'red',
#    'and',
#    'green',
#    'trees']},
#  {'verbs': [{'verb': 'walking',
#     'description': 'An airport with [ARG0: lots of people] [V: walking] [ARGM-DIR: to and fro] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'O']},
#    {'verb': 'fro',
#     'description': 'An airport with [ARG1: lots of people] walking to and [V: fro] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O']}],
#   'words': ['An',
#    'airport',
#    'with',
#    'lots',
#    'of',
#    'people',
#    'walking',
#    'to',
#    'and',
#    'fro',
#    '.']},
#  {'verbs': [{'verb': 'hanging',
#     'description': '[ARG1: umbrella] [V: hanging] [ARG2: fron] [ARG1: the ceiling] of a terminal',
#     'tags': ['B-ARG1', 'B-V', 'B-ARG2', 'B-ARG1', 'I-ARG1', 'O', 'O', 'O']},
#    {'verb': 'fron',
#     'description': '[ARG1: umbrella] hanging [V: fron] [ARG1: the ceiling of a terminal]',
#     'tags': ['B-ARG1',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1']}],
#   'words': ['umbrella',
#    'hanging',
#    'fron',
#    'the',
#    'ceiling',
#    'of',
#    'a',
#    'terminal']},
#  {'verbs': [{'verb': 'are',
#     'description': 'There [V: are] [ARG1: many decorative umbrellas] [ARGM-LOC: on the ceiling] .',
#     'tags': ['O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['There',
#    'are',
#    'many',
#    'decorative',
#    'umbrellas',
#    'on',
#    'the',
#    'ceiling',
#    '.']},
#  {'verbs': [{'verb': 'hanging',
#     'description': 'A room with [ARG1: Chinese hangings] [V: hanging] [ARG2: from the ceiling] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'room',
#    'with',
#    'Chinese',
#    'hangings',
#    'hanging',
#    'from',
#    'the',
#    'ceiling',
#    '.']},
#  {'verbs': [{'verb': 'shopping',
#     'description': '[ARG0: several customers] [V: shopping] [ARGM-LOC: at their local shopping mall]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC']}],
#   'words': ['several',
#    'customers',
#    'shopping',
#    'at',
#    'their',
#    'local',
#    'shopping',
#    'mall']},
#  {'verbs': [{'verb': 'wearing',
#     'description': '[ARG0: A young girl] [V: wearing] [ARG1: a red tie] is adjusting her glasses .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'is',
#     'description': 'A young girl wearing a red tie [V: is] adjusting her glasses .',
#     'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O']},
#    {'verb': 'adjusting',
#     'description': '[ARG0: A young girl wearing a red tie] is [V: adjusting] [ARG1: her glasses] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A',
#    'young',
#    'girl',
#    'wearing',
#    'a',
#    'red',
#    'tie',
#    'is',
#    'adjusting',
#    'her',
#    'glasses',
#    '.']},
#  {'verbs': [],
#   'words': ['A',
#    'person',
#    'with',
#    'glasses',
#    'and',
#    'a',
#    'tie',
#    'in',
#    'a',
#    'room',
#    '.']},
#  {'verbs': [{'verb': 'wearing',
#     'description': '[ARG0: a woman] [V: wearing] [ARG1: glasses] [ARG1: a shirt and tie]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1']},
#    {'verb': 'tie',
#     'description': 'a woman wearing glasses a shirt and [V: tie]',
#     'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-V']}],
#   'words': ['a', 'woman', 'wearing', 'glasses', 'a', 'shirt', 'and', 'tie']},
#  {'verbs': [{'verb': 'wearing',
#     'description': "[ARG0: The man] [V: wearing] [ARG1: a red tie] is standing near an animal 's plastic house .",
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'is',
#     'description': "The man wearing a red tie [V: is] standing near an animal 's plastic house .",
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'standing',
#     'description': "[ARG1: The man wearing a red tie] is [V: standing] [ARG2: near an animal 's plastic house] .",
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['The',
#    'man',
#    'wearing',
#    'a',
#    'red',
#    'tie',
#    'is',
#    'standing',
#    'near',
#    'an',
#    'animal',
#    "'s",
#    'plastic',
#    'house',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'The man in the red tie [V: is] putting on his glasses .',
#     'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'putting',
#     'description': '[ARG0: The man in the red tie] is [V: putting] on [ARG1: his glasses] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['The',
#    'man',
#    'in',
#    'the',
#    'red',
#    'tie',
#    'is',
#    'putting',
#    'on',
#    'his',
#    'glasses',
#    '.']},
#  {'verbs': [],
#   'words': ['A',
#    'man',
#    'in',
#    'a',
#    'white',
#    'pants',
#    'and',
#    'a',
#    'white',
#    'shirt',
#    'and',
#    'colorful',
#    'tie',
#    '.']},
#  {'verbs': [],
#   'words': ['Man',
#    'in',
#    'light',
#    'tone',
#    'clothes',
#    'with',
#    'colorful',
#    'tie',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'There [V: is] [ARG1: a man with glasses wearing a colorful tie]',
#     'tags': ['O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1']},
#    {'verb': 'wearing',
#     'description': 'There is [ARG0: a man with glasses] [V: wearing] [ARG1: a colorful tie]',
#     'tags': ['O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1']}],
#   'words': ['There',
#    'is',
#    'a',
#    'man',
#    'with',
#    'glasses',
#    'wearing',
#    'a',
#    'colorful',
#    'tie']},
#  {'verbs': [],
#   'words': ['A',
#    'short',
#    'man',
#    'in',
#    'a',
#    'short',
#    'sleeve',
#    'dress',
#    'shirt',
#    '.']},
#  {'verbs': [{'verb': 'dressed',
#     'description': '[ARG1: A man] [V: dressed] [ARG2: in white] is smiling for a picture',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'is',
#     'description': 'A man dressed in white [V: is] smiling for a picture',
#     'tags': ['O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O']},
#    {'verb': 'smiling',
#     'description': '[ARG0: A man dressed in white] is [V: smiling] [ARGM-PRP: for a picture]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'B-ARGM-PRP',
#      'I-ARGM-PRP',
#      'I-ARGM-PRP']}],
#   'words': ['A',
#    'man',
#    'dressed',
#    'in',
#    'white',
#    'is',
#    'smiling',
#    'for',
#    'a',
#    'picture']},
#  {'verbs': [{'verb': 'is',
#     'description': 'a male [V: is] riding an elephant next to some water',
#     'tags': ['O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'riding',
#     'description': '[ARG0: a male] is [V: riding] [ARG1: an elephant] [ARGM-LOC: next to some water]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC']}],
#   'words': ['a',
#    'male',
#    'is',
#    'riding',
#    'an',
#    'elephant',
#    'next',
#    'to',
#    'some',
#    'water']},
#  {'verbs': [{'verb': 'standing',
#     'description': '[ARG1: A small gray elephant] [V: standing] [ARG2: on a beach] [ARGM-LOC: next to a lake] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['A',
#    'small',
#    'gray',
#    'elephant',
#    'standing',
#    'on',
#    'a',
#    'beach',
#    'next',
#    'to',
#    'a',
#    'lake',
#    '.']},
#  {'verbs': [{'verb': 'rides',
#     'description': '[ARG0: a man in a hat] [V: rides] [ARG1: an elephant] [ARGM-LOC: in a river]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC']}],
#   'words': ['a',
#    'man',
#    'in',
#    'a',
#    'hat',
#    'rides',
#    'an',
#    'elephant',
#    'in',
#    'a',
#    'river']},
#  {'verbs': [{'verb': 'sitting',
#     'description': '[ARG1: A man] [V: sitting] [ARG2: on a large elephant that is standing in water] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']},
#    {'verb': 'is',
#     'description': 'A man sitting on a large elephant that [V: is] standing in water .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'standing',
#     'description': 'A man sitting on [ARG1: a large elephant] [R-ARG1: that] is [V: standing] [ARG2: in water] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-R-ARG1',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'man',
#    'sitting',
#    'on',
#    'a',
#    'large',
#    'elephant',
#    'that',
#    'is',
#    'standing',
#    'in',
#    'water',
#    '.']},
#  {'verbs': [{'verb': 'rides',
#     'description': '[ARG0: A man] [V: rides] [ARG1: an elephant that has a chain wrapped around his foot in a water way] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'has',
#     'description': 'A man rides [ARG0: an elephant] [R-ARG0: that] [V: has] [ARG1: a chain wrapped around his foot in a water way] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'B-ARG0',
#      'I-ARG0',
#      'B-R-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'wrapped',
#     'description': 'A man rides an elephant that has [ARG2: a chain] [V: wrapped] [ARG1: around his foot] [ARGM-MNR: in a water way] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG2',
#      'I-ARG2',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
# ...
#    {'verb': 'taking',
#     'description': '[ARG0: A child wearing a costume] is [V: taking] [ARG1: a bite of food] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A',
#    'child',
#    'wearing',
#    'a',
#    'costume',
#    'is',
#    'taking',
#    'a',
#    'bite',
#    'of',
#    'food',
#    '.']},
#  {'verbs': [{'verb': 'dressed',
#     'description': '[ARG1: A little kid] [V: dressed] [ARG2: in a costume] , eating some food .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'eating',
#     'description': '[ARG0: A little kid dressed in a costume] , [V: eating] [ARG1: some food] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A',
#    'little',
#    'kid',
#    'dressed',
#    'in',
#    'a',
#    'costume',
#    ',',
#    'eating',
#    'some',
#    'food',
#    '.']},
#  {'verbs': [{'verb': 'wearing',
#     'description': '[ARG0: A boy] [V: wearing] [ARG1: a black , red and yellow superhero costume] and wearing a painted - on black - and - white ` ` eye mask ` ` eats something from a sheet of white wax paper .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'wearing',
#     'description': '[ARG0: A boy] wearing a black , red and yellow superhero costume and [V: wearing] [ARG1: a painted - on black - and - white ` ` eye mask ` `] eats something from a sheet of white wax paper .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'painted',
#     'description': 'A boy wearing a black , red and yellow superhero costume and wearing a [V: painted] - on black - and - white ` ` eye [ARG1: mask] ` ` eats something from a sheet of white wax paper .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'eats',
#     'description': '[ARG0: A boy wearing a black , red and yellow superhero costume and wearing a painted - on black - and - white ` ` eye mask ` `] [V: eats] [ARG1: something] [ARG2: from a sheet of white wax paper] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'boy',
#    'wearing',
#    'a',
#    'black',
#    ',',
#    'red',
#    'and',
#    'yellow',
#    'superhero',
#    'costume',
#    'and',
#    'wearing',
#    'a',
#    'painted',
#    '-',
#    'on',
#    'black',
#    '-',
#    'and',
#    '-',
#    'white',
#    '`',
#    '`',
#    'eye',
#    'mask',
#    '`',
#    '`',
#    'eats',
#    'something',
#    'from',
#    'a',
#    'sheet',
#    'of',
#    'white',
#    'wax',
#    'paper',
#    '.']},
#  {'verbs': [{'verb': 'bounces',
#     'description': '[ARG0: A woman] [V: bounces] [ARG1: a tennis ball] [ARGM-LOC: on a tennis racket] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['A',
#    'woman',
#    'bounces',
#    'a',
#    'tennis',
#    'ball',
#    'on',
#    'a',
#    'tennis',
#    'racket',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'A woman [V: is] hitting a tennis ball with her racket .',
#     'tags': ['O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'hitting',
#     'description': '[ARG0: A woman] is [V: hitting] [ARG1: a tennis ball] [ARG2: with her racket] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'woman',
#    'is',
#    'hitting',
#    'a',
#    'tennis',
#    'ball',
#    'with',
#    'her',
#    'racket',
#    '.']},
#  {'verbs': [{'verb': 'bouncing',
#     'description': '[ARG0: A woman] [V: bouncing] [ARG1: a ball] [ARGM-DIR: off her tennis racket] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'O']}],
#   'words': ['A',
#    'woman',
#    'bouncing',
#    'a',
#    'ball',
#    'off',
#    'her',
#    'tennis',
#    'racket',
#    '.']},
#  {'verbs': [{'verb': 'bounces',
#     'description': '[ARG0: The tennis player with the green ribbon] [V: bounces] [ARG1: the ball] [ARGM-DIR: on her racket] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'B-ARGM-DIR',
#      'I-ARGM-DIR',
#      'I-ARGM-DIR',
#      'O']}],
#   'words': ['The',
#    'tennis',
#    'player',
#    'with',
#    'the',
#    'green',
#    'ribbon',
#    'bounces',
#    'the',
#    'ball',
#    'on',
#    'her',
#    'racket',
#    '.']},
#  {'verbs': [],
#   'words': ['a',
#    'person',
#    'with',
#    'a',
#    'tennis',
#    'racket',
#    'and',
#    'a',
#    'ball']},
#  {'verbs': [{'verb': 'sit',
#     'description': '[ARG1: Two children] [V: sit] [ARG2: at the kitchen bar] [ARGM-ADV: waiting for their meal] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'B-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'I-ARGM-ADV',
#      'O']},
#    {'verb': 'waiting',
#     'description': '[ARG1: Two children] sit at the kitchen bar [V: waiting] [ARG2: for their meal] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['Two',
#    'children',
#    'sit',
#    'at',
#    'the',
#    'kitchen',
#    'bar',
#    'waiting',
#    'for',
#    'their',
#    'meal',
#    '.']},
#  {'verbs': [{'verb': 'being',
#     'description': 'Kids in the kitchen [V: being] served some food by their mom .',
#     'tags': ['O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'served',
#     'description': '[ARG2: Kids in the kitchen] being [V: served] [ARG1: some food] [ARG0: by their mom] .',
#     'tags': ['B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O']}],
#   'words': ['Kids',
#    'in',
#    'the',
#    'kitchen',
#    'being',
#    'served',
#    'some',
#    'food',
#    'by',
#    'their',
#    'mom',
#    '.']},
#  {'verbs': [{'verb': 'enjoys',
#     'description': '[ARG0: A young girl] [V: enjoys] [ARG1: a slice of fresh baked pizza] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A',
#    'young',
#    'girl',
#    'enjoys',
#    'a',
#    'slice',
#    'of',
#    'fresh',
#    'baked',
#    'pizza',
#    '.']},
#  {'verbs': [{'verb': 'eating',
#     'description': '[ARG0: A family] [V: eating] [ARG1: pizza] [ARGM-LOC: at the kitchen bar] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['A',
#    'family',
#    'eating',
#    'pizza',
#    'at',
#    'the',
#    'kitchen',
#    'bar',
#    '.']},
#  {'verbs': [{'verb': 'eating',
#     'description': '[ARG0: a group of people] [V: eating] [ARG1: food] [ARGM-LOC: in a kitchen]',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC']}],
#   'words': ['a',
#    'group',
#    'of',
#    'people',
#    'eating',
#    'food',
#    'in',
#    'a',
#    'kitchen']},
#  {'verbs': [],
#   'words': ['A',
#    'laptop',
#    'computer',
#    'with',
#    'pictures',
#    'of',
#    'giraffes',
#    'on',
#    'the',
#    'homescreen',
#    '.']},
#  {'verbs': [{'verb': 'IS',
#     'description': '[ARG1: THIS] [V: IS] [ARG2: A PICTURE OF SOMEONES ELECTRONIC COLLECTION]',
#     'tags': ['B-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2']}],
#   'words': ['THIS',
#    'IS',
#    'A',
#    'PICTURE',
#    'OF',
#    'SOMEONES',
#    'ELECTRONIC',
#    'COLLECTION']},
#  {'verbs': [{'verb': 'sitting',
#     'description': 'a laptop computer open with [ARG1: a cell phone and camera] [V: sitting] [ARG2: on it]',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2']}],
#   'words': ['a',
#    'laptop',
#    'computer',
#    'open',
#    'with',
#    'a',
#    'cell',
#    'phone',
#    'and',
#    'camera',
#    'sitting',
#    'on',
#    'it']},
#  {'verbs': [{'verb': 'sitting',
#     'description': '[ARG1: A laptop computer] [V: sitting] [ARG2: on top of a purple table] .',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'laptop',
#    'computer',
#    'sitting',
#    'on',
#    'top',
#    'of',
#    'a',
#    'purple',
#    'table',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'There [V: is] [ARG1: a digital camera , flash drive , and cellphone] [ARGM-LOC: on top of a laptop computer] .',
#     'tags': ['O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'I-ARGM-LOC',
#      'O']}],
#   'words': ['There',
#    'is',
#    'a',
#    'digital',
#    'camera',
#    ',',
#    'flash',
#    'drive',
#    ',',
#    'and',
#    'cellphone',
#    'on',
#    'top',
#    'of',
#    'a',
#    'laptop',
#    'computer',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'A person who [V: is] taking a picture of something with his phone .',
#     'tags': ['O',
#      'O',
#      'O',
#      'B-V',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O']},
#    {'verb': 'taking',
#     'description': '[ARG0: A person] [R-ARG0: who] is [V: taking] [ARG1: a picture of something] [ARGM-MNR: with his phone] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'B-R-ARG0',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'O']}],
#   'words': ['A',
#    'person',
#    'who',
#    'is',
#    'taking',
#    'a',
#    'picture',
#    'of',
#    'something',
#    'with',
#    'his',
#    'phone',
#    '.']},
#  {'verbs': [{'verb': 'are',
#     'description': '[ARG1: a couple of men in white] [V: are] [ARG2: in a kitchen]',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2']}],
#   'words': ['a',
#    'couple',
#    'of',
#    'men',
#    'in',
#    'white',
#    'are',
#    'in',
#    'a',
#    'kitchen']},
#  {'verbs': [{'verb': 'looking',
#     'description': '[ARG0: A man in military uniform] [V: looking] [ARG1: at his phone] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A',
#    'man',
#    'in',
#    'military',
#    'uniform',
#    'looking',
#    'at',
#    'his',
#    'phone',
#    '.']},
#  {'verbs': [{'verb': 'is',
#     'description': 'A man in a uniform [V: is] using a mobile device .',
#     'tags': ['O', 'O', 'O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O']},
#    {'verb': 'using',
#     'description': '[ARG0: A man in a uniform] is [V: using] [ARG1: a mobile device] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'O',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A',
#    'man',
#    'in',
#    'a',
#    'uniform',
#    'is',
#    'using',
#    'a',
#    'mobile',
#    'device',
#    '.']},
#  {'verbs': [],
#   'words': ['some',
#    'people',
#    'and',
#    'a',
#    'male',
#    'in',
#    'a',
#    'white',
#    'jacket',
#    'and',
#    'his',
#    'cellphone']},
#  {'verbs': [{'verb': 'has',
#     'description': '[ARG0: A cell phone] [V: has] [ARG1: a ritz cracker like keychain] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']}],
#   'words': ['A',
#    'cell',
#    'phone',
#    'has',
#    'a',
#    'ritz',
#    'cracker',
#    'like',
#    'keychain',
#    '.']},
#  {'verbs': [{'verb': 'attached',
#     'description': 'A smart phone on top of a table with [ARG1: a cookie] [V: attached] [ARG2: to it] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'O']}],
#   'words': ['A',
#    'smart',
#    'phone',
#    'on',
#    'top',
#    'of',
#    'a',
#    'table',
#    'with',
#    'a',
#    'cookie',
#    'attached',
#    'to',
#    'it',
#    '.']},
#  {'verbs': [{'verb': 'hooked',
#     'description': '[ARG1: a big round yellow thing] [V: hooked] [ARG2: on a cell phone]',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2']}],
#   'words': ['a',
#    'big',
#    'round',
#    'yellow',
#    'thing',
#    'hooked',
#    'on',
#    'a',
#    'cell',
#    'phone']},
#  {'verbs': [{'verb': 'has',
#     'description': '[ARG0: The mobile phone] [V: has] [ARG1: a trinket attached to it by a cord] .',
#     'tags': ['B-ARG0',
#      'I-ARG0',
#      'I-ARG0',
#      'B-V',
#      'B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'O']},
#    {'verb': 'attached',
#     'description': 'The mobile phone has [ARG1: a trinket] [V: attached] [ARG2: to it] [ARGM-MNR: by a cord] .',
#     'tags': ['O',
#      'O',
#      'O',
#      'O',
#      'B-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'B-ARGM-MNR',
#      'I-ARGM-MNR',
#      'I-ARGM-MNR',
#      'O']}],
#   'words': ['The',
#    'mobile',
#    'phone',
#    'has',
#    'a',
#    'trinket',
#    'attached',
#    'to',
#    'it',
#    'by',
#    'a',
#    'cord',
#    '.']},
#  {'verbs': [{'verb': 'attached',
#     'description': '[ARG1: A rubber cookie key ring] [V: attached] [ARG2: to a cell phone]',
#     'tags': ['B-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'I-ARG1',
#      'B-V',
#      'B-ARG2',
#      'I-ARG2',
#      'I-ARG2',
#      'I-ARG2']}],
#   'words': ['A',
#    'rubber',
#    'cookie',
#    'key',
#    'ring',
#    'attached',
#    'to',
#    'a',
#    'cell',
#    'phone']}]
